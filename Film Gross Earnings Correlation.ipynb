# %%
# Import packages required for project

import pandas as pd
import numpy as np
import seaborn as sns


import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

#read in the data

df=pd.read_csv(r'/Users/danyfarias/Desktop/Portfolio Projects/Project #4/movies.csv')

# %%
#View data

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
#check for missing data/Nulls

for col in df.columns:
    pct_missing=np.mean(df[col].isnull())
    print('{} - {}%'.format(col,pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
# data type for columns

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#clean currency columns data types
#In looking at the captured columns there are some non-numeric values that need to be sorted before data type 
    # change can occur. 
    
# Replace NaN and inf with a default value, e.g., 0 in both Budget & Gross Columns
df['budget'].fillna(0, inplace=True)  # Replace NaN with 0
df.replace([np.inf, -np.inf], 0, inplace=True)  # Replace inf with 0

df['gross'].fillna(0, inplace=True)  # Replace NaN with 0
df.replace([np.inf, -np.inf], 0, inplace=True)  # Replace inf with 0

# Convert 'budget' column to integer
df['budget'] = df['budget'].astype('int64')
df['gross']=df['gross'].astype('int64')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
#Check current state of data types after converting types.

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime     float64
# dtype: object

# %%
#correct year column as released date years do not always match year column.

# Remove "(United States)" from 'released' column, found that there is more string in paren so adjusted code below.
#atmp1: df['released'] = df['released'].str.replace(r'\s*\(United States\)', '')

df['released'] = df['released'].str.replace(r'\s*\([^)]*\)', '')

df['yearcorrected']=df['released'].astype(str).str[-4:]
df.head()
# Out:
# /var/folders/mb/fmhzdctd7pn64c7dx37vjyg40000gn/T/ipykernel_2124/738639665.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['released'] = df['released'].str.replace(r'\s*\([^)]*\)', '')
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#         released  score      votes         director                   writer  \
# 0  June 13, 1980    8.4   927000.0  Stanley Kubrick             Stephen King
# 1   July 2, 1980    5.8    65000.0   Randal Kleiser  Henry De Vere Stacpoole
# ...

# %%
df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name rating    genre  year  \
# 5445                                      Avatar  PG-13   Action  2009
# 7445                           Avengers: Endgame  PG-13   Action  2019
# 3045                                     Titanic  PG-13    Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13   Action  2015
# 7244                      Avengers: Infinity War  PG-13   Action  2018
# ...                                          ...    ...      ...   ...
# 1617                             Mortal Passions      R    Crime  1989
# 1614                              Edge of Sanity      R   Horror  1989
# 1606                                   I, Madman      R  Fantasy  1989
# 1601                        My Twentieth Century    NaN   Comedy  1989
# 7667                                   Tee em el    NaN   Horror  2020
#
#                released  score      votes        director              writer  \
# ...

# %%
#expand row view 
#pd.set_option('display.max_rows',None)
pd.set_option('display.min_rows',None)
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#         released  score      votes         director                   writer  \
# 0  June 13, 1980    8.4   927000.0  Stanley Kubrick             Stephen King
# 1   July 2, 1980    5.8    65000.0   Randal Kleiser  Henry De Vere Stacpoole
# 2  June 20, 1980    8.7  1200000.0   Irvin Kershner           Leigh Brackett
# 3   July 2, 1980    7.7   221000.0     Jim Abrahams             Jim Abrahams
# 4  July 25, 1980    7.3   108000.0     Harold Ramis       Brian Doyle-Murray
#
# ...

# %%
#Look for dups and drop if any, No dups exists as row count remains equal on current df to prior df.

df.drop_duplicates()
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# 5                                    Friday the 13th          R     Horror
# 6                                 The Blues Brothers          R     Action
# 7                                        Raging Bull          R  Biography
# 8                                        Superman II         PG     Action
# 9                                    The Long Riders          R  Biography
# 10                             Any Which Way You Can         PG     Action
# ...

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#         released  score      votes         director                   writer  \
# 0  June 13, 1980    8.4   927000.0  Stanley Kubrick             Stephen King
# 1   July 2, 1980    5.8    65000.0   Randal Kleiser  Henry De Vere Stacpoole
# 2  June 20, 1980    8.7  1200000.0   Irvin Kershner           Leigh Brackett
# 3   July 2, 1980    7.7   221000.0     Jim Abrahams             Jim Abrahams
# 4  July 25, 1980    7.3   108000.0     Harold Ramis       Brian Doyle-Murray
#
# ...

# %%
#Budget & Company - High Correlation to Revenue?

# %%
#scatter plot with budget vs gross

plt.scatter(x=df['budget'],y=df['gross'])

plt.title('Budget vs Earnings')

plt.xlabel('Gross Earnings')
plt.ylabel('Budget for Film')

plt.show()

# %%
df=df.sort_values(by=['gross'], inplace=False, ascending=False)
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                released  score      votes       director              writer  \
# 5445  December 18, 2009    7.8  1100000.0  James Cameron       James Cameron
# 7445     April 26, 2019    8.4   903000.0  Anthony Russo  Christopher Markus
# 3045  December 19, 1997    7.8  1100000.0  James Cameron       James Cameron
# 6663  December 18, 2015    7.8   876000.0    J.J. Abrams     Lawrence Kasdan
# 7244     April 27, 2018    8.4   897000.0  Anthony Russo  Christopher Markus
#
#                    star        country     budget       gross  \
# ...

# %%
#plot budget versus gross using seaborn, shows correlation, but how much?

sns.regplot(x='budget',y='gross', data=df, scatter_kws={"color": "red"}, line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
#looking at correlation only numeric fields when using .corr Correlation Methods: Pearson, kendall, spearman

df.corr(method='pearson')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.309212  0.261900  0.120811
# score    0.097995  1.000000  0.409182  0.055665  0.186392  0.399451
# votes    0.222945  0.409182  1.000000  0.486862  0.632834  0.309212
# budget   0.309212  0.055665  0.486862  1.000000  0.750157  0.269510
# gross    0.261900  0.186392  0.632834  0.750157  1.000000  0.245235
# runtime  0.120811  0.399451  0.309212  0.269510  0.245235  1.000000

# %%
#High correlation between budget and gross - Correct assumption

# %%
#Visualize Table above

correlation_matrix = df.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation of Numeric Features')

plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
# Look at company correlation 

df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                released  score      votes       director              writer  \
# 5445  December 18, 2009    7.8  1100000.0  James Cameron       James Cameron
# 7445     April 26, 2019    8.4   903000.0  Anthony Russo  Christopher Markus
# 3045  December 19, 1997    7.8  1100000.0  James Cameron       James Cameron
# 6663  December 18, 2015    7.8   876000.0    J.J. Abrams     Lawrence Kasdan
# 7244     April 27, 2018    8.4   897000.0  Anthony Russo  Christopher Markus
#
#                    star        country     budget       gross  \
# ...

# %%
#Loop & Convert company to object type to evaluate correlation

df_num=df

for col_name in df_num.columns:
    if(df_num[col_name].dtype== 'object'):
        df_num[col_name]= df_num[col_name].astype('category')
        df_num[col_name]= df_num[col_name].cat.codes

df_num.head()
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   533       5      0  2009       610    7.8  1100000.0      1155    1778
# 7445   535       5      0  2019       153    8.4   903000.0       162     743
# 3045  6896       5      6  1997       616    7.8  1100000.0      1155    1778
# 6663  5144       5      0  2015       612    7.8   876000.0      1125    2550
# 7244   536       5      0  2018       161    8.4   897000.0       162     743
#
#       star  country     budget       gross  company  runtime  yearcorrected
# 5445  2334       55  237000000  2847246203     2253    162.0             29
# 7445  2241       55  356000000  2797501328     1606    181.0             39
# 3045  1595       55  200000000  2201647264     2253    194.0             17
# 6663   524       55  245000000  2069521700     1540    138.0             35
# 7244  2241       55  321000000  2048359754     1606    149.0             38

# %%
#Prior version of frame will displays with original string field rerun base table to capture in below output.

df.head()
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   533       5      0  2009       610    7.8  1100000.0      1155    1778
# 7445   535       5      0  2019       153    8.4   903000.0       162     743
# 3045  6896       5      6  1997       616    7.8  1100000.0      1155    1778
# 6663  5144       5      0  2015       612    7.8   876000.0      1125    2550
# 7244   536       5      0  2018       161    8.4   897000.0       162     743
#
#       star  country     budget       gross  company  runtime  yearcorrected
# 5445  2334       55  237000000  2847246203     2253    162.0             29
# 7445  2241       55  356000000  2797501328     1606    181.0             39
# 3045  1595       55  200000000  2201647264     2253    194.0             17
# 6663   524       55  245000000  2069521700     1540    138.0             35
# 7244  2241       55  321000000  2048359754     1606    149.0             38

# %%
#Visualize Table above

correlation_matrix = df_num.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation of Numeric Features')

plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
df_num.corr()
# Out:
#                    name    rating     genre      year  released     score  \
# name           1.000000 -0.008069  0.016355  0.011453 -0.011223  0.017097
# rating        -0.008069  1.000000  0.072423  0.008779  0.015735 -0.001314
# genre          0.016355  0.072423  1.000000 -0.081261  0.029039  0.027965
# year           0.011453  0.008779 -0.081261  1.000000 -0.000832  0.097995
# released      -0.011223  0.015735  0.029039 -0.000832  1.000000  0.042918
# score          0.017097 -0.001314  0.027965  0.097995  0.042918  1.000000
# votes          0.013088  0.033225 -0.145307  0.222945  0.017111  0.409182
# director       0.009079  0.019483 -0.015258 -0.020795 -0.001275  0.009559
# writer         0.009081 -0.005921  0.006567 -0.008656 -0.002421  0.019416
# star           0.006472  0.013405 -0.005477 -0.027242  0.015597 -0.001609
# country       -0.010737  0.081244 -0.037615 -0.070938 -0.020063 -0.133348
# budget         0.020548 -0.081939 -0.334021  0.309212  0.010643  0.055665
# ...

# %%
correlation_mat = df_num.corr()
corrs_pairs=correlation_mat.unstack()

corrs_pairs
# Out:
# name           name             1.000000
#                rating          -0.008069
#                genre            0.016355
#                year             0.011453
#                released        -0.011223
#                score            0.017097
#                votes            0.013088
#                director         0.009079
#                writer           0.009081
#                star             0.006472
#                country         -0.010737
#                budget           0.020548
#                gross            0.006989
#                company          0.009211
#                runtime          0.010392
#                yearcorrected    0.011134
# rating         name            -0.008069
#                rating           1.000000
#                genre            0.072423
#                year             0.008779
#                released         0.015735
#                score           -0.001314
#                votes            0.033225
# ...

# %%
sorted_pairs= corrs_pairs.sort_values()
sorted_pairs
# Out:
# genre          budget          -0.334021
# budget         genre           -0.334021
# gross          genre           -0.234297
# genre          gross           -0.234297
# votes          genre           -0.145307
# genre          votes           -0.145307
# score          country         -0.133348
# country        score           -0.133348
# rating         gross           -0.095450
# gross          rating          -0.095450
# country        yearcorrected   -0.082274
# yearcorrected  country         -0.082274
# rating         budget          -0.081939
# budget         rating          -0.081939
# year           genre           -0.081261
# genre          year            -0.081261
# country        runtime         -0.078412
# runtime        country         -0.078412
# yearcorrected  genre           -0.077550
# genre          yearcorrected   -0.077550
#                company         -0.071067
# company        genre           -0.071067
# year           country         -0.070938
# ...

# %%
high_corr = sorted_pairs[(sorted_pairs)>0.5]

high_corr
# Out:
# gross          votes            0.632834
# votes          gross            0.632834
# budget         gross            0.750157
# gross          budget           0.750157
# year           yearcorrected    0.997295
# yearcorrected  year             0.997295
# name           name             1.000000
# company        company          1.000000
# gross          gross            1.000000
# budget         budget           1.000000
# country        country          1.000000
# star           star             1.000000
# writer         writer           1.000000
# director       director         1.000000
# votes          votes            1.000000
# score          score            1.000000
# released       released         1.000000
# year           year             1.000000
# genre          genre            1.000000
# rating         rating           1.000000
# runtime        runtime          1.000000
# yearcorrected  yearcorrected    1.000000
# dtype: float64

# %%
##company does not have a high correlation, however gross and votes have the highest correlation to gross earnings.
